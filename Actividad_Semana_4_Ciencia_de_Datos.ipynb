# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-del-projecto-equipo_36/blob/main/Actividad_Semana_4_Ciencia_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Maestría en Inteligencia Artificial Aplicada**
# ##**Ciencia y Analítica de Datos**
# ###Tecnológico de Monterrey
# ###Prof Titular: **Jobish Vallikavungal Devassia**
# ###Tutor: **Roberto Antonio Guevara González**

# %% [markdown]
# ### **Actividasd Semana - 4**
# ####**Equipo 36**
# ####*Marcos Chávez - A01688507*
# ####*Rodrigo Pepi - A01382430*
#
# https://github.com/PosgradoMNA/actividades-del-projecto-equipo_36/blob/main/Actividad_Semana_3_Ciencia_de_Datos.ipynb
#
# ####*Fecha de entrega 11/10/2022*

# %%
import pandas as pd
import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = 'https://raw.githubusercontent.com/PosgradoMNA/Actividades_Aprendizaje-/main/default%20of%20credit%20card%20clients.csv'

# %%
df = pd.read_csv(data, sep=',')
df
# Out:
#           ID      X1   X2   X3   X4    X5   X6   X7   X8   X9  ...      X15  \
# 0          1   20000  2.0  2.0  1.0  24.0  2.0  2.0 -1.0 -1.0  ...      0.0
# 1          2  120000  2.0  2.0  2.0  26.0 -1.0  2.0  0.0  0.0  ...   3272.0
# 2          3   90000  2.0  2.0  2.0  34.0  0.0  0.0  0.0  0.0  ...  14331.0
# 3          4   50000  2.0  2.0  1.0  37.0  0.0  0.0  0.0  0.0  ...  28314.0
# 4          5   50000  1.0  2.0  1.0  57.0 -1.0  0.0 -1.0  0.0  ...  20940.0
# ...      ...     ...  ...  ...  ...   ...  ...  ...  ...  ...  ...      ...
# 29995  29996  220000  1.0  3.0  1.0  39.0  0.0  0.0  0.0  0.0  ...  88004.0
# 29996  29997  150000  1.0  3.0  2.0  43.0 -1.0 -1.0 -1.0 -1.0  ...   8979.0
# 29997  29998   30000  1.0  2.0  2.0  37.0  4.0  3.0  2.0 -1.0  ...  20878.0
# 29998  29999   80000  1.0  3.0  1.0  41.0  1.0 -1.0  0.0  0.0  ...  52774.0
# 29999  30000   50000  1.0  2.0  1.0  46.0  0.0  0.0  0.0  0.0  ...  36535.0
#
# ...

# %%
df = df.fillna(0).astype('int64').copy() #Sustituye nulos y visualizar enteros datos en enteros
df
# Out:
#           ID      X1  X2  X3  X4  X5  X6  X7  X8  X9  ...    X15    X16  \
# 0          1   20000   2   2   1  24   2   2  -1  -1  ...      0      0
# 1          2  120000   2   2   2  26  -1   2   0   0  ...   3272   3455
# 2          3   90000   2   2   2  34   0   0   0   0  ...  14331  14948
# 3          4   50000   2   2   1  37   0   0   0   0  ...  28314  28959
# 4          5   50000   1   2   1  57  -1   0  -1   0  ...  20940  19146
# ...      ...     ...  ..  ..  ..  ..  ..  ..  ..  ..  ...    ...    ...
# 29995  29996  220000   1   3   1  39   0   0   0   0  ...  88004  31237
# 29996  29997  150000   1   3   2  43  -1  -1  -1  -1  ...   8979   5190
# 29997  29998   30000   1   2   2  37   4   3   2  -1  ...  20878  20582
# 29998  29999   80000   1   3   1  41   1  -1   0   0  ...  52774  11855
# 29999  30000   50000   1   2   1  46   0   0   0   0  ...  36535  32428
#
#          X17    X18    X19    X20   X21    X22   X23  Y
# ...

# %% [markdown]
# Correlation between result and variables

# %%
cdf = df.iloc[:,1:25] #Omite las variable ID
cdf
# Out:
#            X1  X2  X3  X4  X5  X6  X7  X8  X9  X10  ...    X15    X16    X17  \
# 0       20000   2   2   1  24   2   2  -1  -1   -2  ...      0      0      0
# 1      120000   2   2   2  26  -1   2   0   0    0  ...   3272   3455   3261
# 2       90000   2   2   2  34   0   0   0   0    0  ...  14331  14948  15549
# 3       50000   2   2   1  37   0   0   0   0    0  ...  28314  28959  29547
# 4       50000   1   2   1  57  -1   0  -1   0    0  ...  20940  19146  19131
# ...       ...  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...    ...    ...    ...
# 29995  220000   1   3   1  39   0   0   0   0    0  ...  88004  31237  15980
# 29996  150000   1   3   2  43  -1  -1  -1  -1    0  ...   8979   5190      0
# 29997   30000   1   2   2  37   4   3   2  -1    0  ...  20878  20582  19357
# 29998   80000   1   3   1  41   1  -1   0   0    0  ...  52774  11855  48944
# 29999   50000   1   2   1  46   0   0   0   0    0  ...  36535  32428  15313
#
# ...

# %%
#Se calculan las correlaciones entre las variables
#cdf.corr()

#Vizualización
sns.set(rc={'figure.figsize':(24,24)}) 
sns.heatmap(cdf.corr(), cmap="BuGn", annot = True)
plt.show()

# %% [markdown]
# Se selecciona X6 para realizar el análisis preliminar por ser las que muestra una correlación mayor con la variable de respuesta.

# %%
Variance = np.cov([cdf.X6,cdf.Y])
Variance # Covarianza entre X6 y Y el resultado
# Out:
# array([[1.26286543, 0.15141712],
#        [0.15141712, 0.17225771]])

# %%
ndf = cdf[['X6','Y']]
ndf.var().sum() # Sumatoria de la varianza de los factores
# Out:
# 1.4351231418825072

# %%
t= ndf.var().sum()
varC =Variance[0][0]
varR = Variance[1][1] # Se analiza el peso o aportación de cada factor a la varianza

# %%
print('Total Varience \t\t\t:', t.round(2) )
print('Varience prop. of X6 \t:', ((varC/t)*100).round(2),'%' )
print('Varience prop. of Y \t:', ((varR/t)*100).round(2),'%' )
# Out:
# Total Varience 			: 1.44
# Varience prop. of X6 	: 88.0 %
# Varience prop. of Y 	: 12.0 %

# %%
ndf.corr().round(2)
# Out:
#       X6     Y
# X6  1.00  0.32
# Y   0.32  1.00

# %%
sns.set(rc={'figure.figsize':(12,12)}) 
p = sns.regplot(data = cdf,  
                x = cdf.X6, 
                y = cdf.Y
               ) # Plot para graficar las razones de cambio lineales
p

# %%
from sklearn.decomposition import PCA
pcs = PCA(n_components=2)

pcs.fit(cdf[['X6', 'Y']])

pcsSummary = pd.DataFrame({'Standard deviation': np.sqrt(pcs.explained_variance_),
                          'Proportion of variance': pcs.explained_variance_ratio_,
                          'Cumulative proportion': np.cumsum(pcs.explained_variance_ratio_)#column 
                          }
                          ) #proporciones de varianza utilizando análisis de componentes principales
pcsSummary
# Out:
#    Standard deviation  Proportion of variance  Cumulative proportion
# 0            1.132915                0.894347               0.894347
# 1            0.389391                0.105653               1.000000

# %%
pcsSummary = pcsSummary.transpose() # Transposición
pcsSummary.round(2)
# Out:
#                            0     1
# Standard deviation      1.13  0.39
# Proportion of variance  0.89  0.11
# Cumulative proportion   0.89  1.00

# %%
pcsSummary.columns = ['PC1', 'PC2'] # Resumen de los dos componentes escogidos
pcsSummary = pcsSummary.round(4)
pcsSummary
# Out:
#                            PC1     PC2
# Standard deviation      1.1329  0.3894
# Proportion of variance  0.8943  0.1057
# Cumulative proportion   0.8943  1.0000

# %% [markdown]
# Con base en los resultados del análisis anterior se observa que el primer componente aporta el 89% de la varianza y con el segundo componente únicamente el 11% restante.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
PC_components = np.arange(pcs.n_components_) + 1
#PC_components

_ = sns.set(style = 'whitegrid', 
            font_scale = 1.2
            )

fig, ax = plt.subplots(figsize=(10, 7))

_ = sns.barplot(x = PC_components, 
                y = pcs.explained_variance_ratio_, 
                color = 'b'
                )

_ = sns.lineplot(x = PC_components-1, 
                 y = np.cumsum(pcs.explained_variance_ratio_), # Este código toma en cuenta los componentes seleccionados para explicar la variación, 
                 color = 'black',                              # En caso de seleccionar todas las variables, se puede mostrar una gráfica esencialmente igual a un pareto
                 linestyle = '-', 
                 linewidth = 2, 
                 marker = 'o', 
                 markersize = 8
                 )

plt.title('Scree Plot')
plt.xlabel('N-th Principal Component')
plt.ylabel('Variance Explained')
plt.ylim(0, 1)
plt.show()

# %%
pcs.components_.round(4) # Es el conjunto de todos los eigenvectores (one eigenvector for each principal component).
# Out:
# array([[ 0.9908,  0.135 ],
#        [ 0.135 , -0.9908]])

# %%
pcsComponents_cdf = pd.DataFrame(pcs.components_.transpose(), 
                                columns=['PC1', 'PC2'],
                                index=['X6', 'X7']
                                )
pcsComponents_cdf
# Out:
#          PC1       PC2
# X6  0.990844  0.135012
# X7  0.135012 -0.990844

# %%
scores = pd.DataFrame(pcs.transform(cdf[['X6', 'Y']]),
                      columns=['x', 'y']
                      )
scores.head()
# Out:
#           x         y
# 0  2.103321 -0.499433
# 1 -0.869211 -0.904469
# 2 -0.013379  0.221387
# 3 -0.013379  0.221387
# 4 -1.004223  0.086375

# %%
cdf.X6.mean().round(2)
# Out:
# -0.02

# %%
cdf.Y.mean().round(2)
# Out:
# 0.22

# %%
x = (.991)*(-.02-2)+(.135)*(1-.22)
y = (.135)*(-.02-2)+(.991)*(1-.22)
print('For the PC1\n \t x = ', x, '\n\t y = ', y) # Se construye modelo lineal para comprobar los resultados anteriormente conseguidos acerca de las varianzas
# Out:
# For the PC1
#  	 x =  -1.89652
# 	 y =  0.5002800000000001

# %%
scores.x.mean()
# Out:
# -5.3053857603420813e-17

# %%
scores.y.sum()
# Out:
# 3.7125857943465235e-13

# %%
scores.x.var() + scores.y.var()
# Out:
# 1.435123141882507

# %%
((scores.x.var()/
  (scores.x.var()+scores.y.var())
 )*100).round(0)
# Out:
# 89.0

# %% [markdown]
# ###Ahora se procede a aplicar esta técnica al resto de la base

# %%
pcs = PCA()
pcs.fit(cdf.dropna(axis=0))
pcsSummary_df = pd.DataFrame({'Standard deviation': np.sqrt(pcs.explained_variance_),
                             'Proportion of variance': pcs.explained_variance_ratio_,
                             'Cumulative proportion': np.cumsum(pcs.explained_variance_ratio_) # En la siguiente matriz se muestran las proporciones acumuladas de la variabilidad, de esta manera 
                             })                                                                # se pueden seleccionar sólamente los componentes principales para reducir la cantidad de información presente
pcsSummary_df = pcsSummary_df.transpose()
pcsSummary_df.round(4)
# Out:
#                                  0            1           2           3   \
# Standard deviation      166526.3231  115824.3723  37236.4283  27730.3966
# Proportion of variance       0.6105       0.2953      0.0305      0.0169
# Cumulative proportion        0.6105       0.9058      0.9363      0.9532
#
#                                 4           5           6           7   \
# Standard deviation      20686.6242  20266.0848  18511.5323  17030.1453
# Proportion of variance      0.0094      0.0090      0.0075      0.0064
# Cumulative proportion       0.9627      0.9717      0.9792      0.9856
#
#                                 8           9   ...      14      15      16  \
# Standard deviation      16283.1702  11608.9772  ...  2.0658  0.9421  0.7532
# Proportion of variance      0.0058      0.0030  ...  0.0000  0.0000  0.0000
# Cumulative proportion       0.9915      0.9944  ...  1.0000  1.0000  1.0000
#
#                             17      18      19     20      21      22      23
# ...

# %%
PC_components = np.arange(pcs.n_components_) + 1
#PC_components

_ = sns.set(style = 'whitegrid', 
            font_scale = 1.2
            )

fig, ax = plt.subplots(figsize=(10, 7))

_ = sns.barplot(x = PC_components, 
                y = pcs.explained_variance_ratio_, 
                color = 'b'
                )

_ = sns.lineplot(x = PC_components-1, 
                 y = np.cumsum(pcs.explained_variance_ratio_), 
                 color = 'black', 
                 linestyle = '-', 
                 linewidth = 2, 
                 marker = 'o', 
                 markersize = 8
                 )

plt.title('Scree Plot')
plt.xlabel('N-th Principal Component')
plt.ylabel('Variance Explained')
plt.ylim(0, 1)
plt.show() # El codigo anterior crea un pareto con los resultados de la matriz anterior para visualmente identificar los mayores contribuidores de información

# %%
#pcsSummary_df.iloc[1][0]+pcsSummary_df.iloc[1][1]+pcsSummary_df.iloc[1][2]
#OR
((pcsSummary_df.iloc[2][0])*100).round(0) # Porcentaje de información presente con el 1er componente
#type(pcsSummary_df)
# Out:
# 61.0

# %%
#pcsSummary_df.iloc[1][0]+pcsSummary_df.iloc[1][1]+pcsSummary_df.iloc[1][2]
#OR
((pcsSummary_df.iloc[2][1])*100).round(0) # Porcentaje de información presente hasta el 2do componente
#type(pcsSummary_df)
# Out:
# 91.0

# %%
#pcsSummary_df.iloc[1][0]+pcsSummary_df.iloc[1][1]
#OR
((pcsSummary_df.iloc[2][2])*100).round(2) # Hasta el 3er componente
# Out:
# 93.63

# %%
pcsSummary_df.columns = ['PC{}'.format(i) for i in range(1, len(pcsSummary_df.columns) + 1)]
pcsSummary_df.round(4) # Se hace la proporción cumulativa de cada uno de los componentes principales, quitando el registro 0
# Out:
#                                 PC1          PC2         PC3         PC4  \
# Standard deviation      166526.3231  115824.3723  37236.4283  27730.3966
# Proportion of variance       0.6105       0.2953      0.0305      0.0169
# Cumulative proportion        0.6105       0.9058      0.9363      0.9532
#
#                                PC5         PC6         PC7         PC8  \
# Standard deviation      20686.6242  20266.0848  18511.5323  17030.1453
# Proportion of variance      0.0094      0.0090      0.0075      0.0064
# Cumulative proportion       0.9627      0.9717      0.9792      0.9856
#
#                                PC9        PC10  ...    PC15    PC16    PC17  \
# Standard deviation      16283.1702  11608.9772  ...  2.0658  0.9421  0.7532
# Proportion of variance      0.0058      0.0030  ...  0.0000  0.0000  0.0000
# Cumulative proportion       0.9915      0.9944  ...  1.0000  1.0000  1.0000
#
#                           PC18    PC19    PC20   PC21    PC22    PC23    PC24
# ...

# %%
pcs.components_
# Out:
# array([[ 4.91580908e-01, -3.49261951e-08, -3.66501908e-07,
#         -1.91995130e-07,  5.56976379e-06,  3.41779544e-07,
#          5.67634549e-07,  5.81562128e-07,  6.64677603e-07,
#          7.57955082e-07,  8.35899411e-07,  3.88452058e-01,
#          3.81355647e-01,  3.72186643e-01,  3.46408073e-01,
#          3.22925051e-01,  3.08568962e-01,  2.65719855e-02,
#          3.12870305e-02,  2.68182892e-02,  2.21697040e-02,
#          2.22045477e-02,  2.48098902e-02, -1.75342532e-07],
#        [ 8.69029069e-01,  1.75800179e-07, -1.49918114e-06,
#         -4.01569503e-07,  8.27792273e-06, -3.80326756e-06,
#         -4.62263794e-06, -4.49685748e-06, -4.25879241e-06,
#         -4.03016410e-06, -3.98251720e-06, -2.21357433e-01,
#         -2.26378765e-01, -2.16514535e-01, -1.94039459e-01,
#         -1.76768081e-01, -1.67383950e-01,  5.71449210e-03,
#          1.07819389e-02,  1.09538993e-02,  1.03613893e-02,
#          1.16820179e-02,  1.53330045e-02, -5.06024919e-07],
# ...

# %%
pcsComponents_df = pd.DataFrame(pcs.components_.transpose(), 
                                columns = pcsSummary_df.columns,
                                index = cdf.columns
                                )
pcsComponents_df.iloc[:,:3] # Se tabulan los arrays anteriores para identificar factores más importantes
# Out:
#               PC1           PC2           PC3
# X1   4.915809e-01  8.690291e-01 -2.057808e-02
# X2  -3.492620e-08  1.758002e-07  3.244874e-07
# X3  -3.665019e-07 -1.499181e-06 -9.730797e-07
# X4  -1.919951e-07 -4.015695e-07  7.375978e-08
# X5   5.569764e-06  8.277923e-06 -4.191445e-06
# X6   3.417795e-07 -3.803268e-06 -4.156828e-07
# X7   5.676345e-07 -4.622638e-06 -5.847159e-07
# X8   5.815621e-07 -4.496857e-06  5.080617e-07
# X9   6.646776e-07 -4.258792e-06  2.100704e-06
# X10  7.579551e-07 -4.030164e-06  3.455139e-06
# X11  8.358994e-07 -3.982517e-06  4.451784e-06
# X12  3.884521e-01 -2.213574e-01 -5.489635e-01
# X13  3.813556e-01 -2.263788e-01 -3.909324e-01
# X14  3.721866e-01 -2.165145e-01 -4.810317e-02
# X15  3.464081e-01 -1.940395e-01  2.610328e-01
# X16  3.229251e-01 -1.767681e-01  4.280921e-01
# X17  3.085690e-01 -1.673840e-01  4.836507e-01
# X18  2.657199e-02  5.714492e-03  3.755053e-02
# X19  3.128703e-02  1.078194e-02  1.600275e-01
# ...

# %%
pcsComponents_dfX = pd.DataFrame(pcs.components_.transpose(), 
                                columns = pcsSummary_df.columns,
                                index = cdf.columns
                                )
pcsComponents_dfX.round(4) # Se transpone la información para su fácil lectura
# Out:
#         PC1     PC2     PC3     PC4     PC5     PC6     PC7     PC8     PC9  \
# X1   0.4916  0.8690 -0.0206 -0.0184 -0.0441  0.0169 -0.0011  0.0010  0.0095
# X2  -0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
# X3  -0.0000 -0.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000 -0.0000  0.0000
# X4  -0.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000  0.0000 -0.0000 -0.0000
# X5   0.0000  0.0000 -0.0000 -0.0000 -0.0000  0.0000 -0.0000 -0.0000  0.0000
# X6   0.0000 -0.0000 -0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000 -0.0000
# X7   0.0000 -0.0000 -0.0000 -0.0000 -0.0000  0.0000 -0.0000  0.0000 -0.0000
# X8   0.0000 -0.0000  0.0000 -0.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
# X9   0.0000 -0.0000  0.0000  0.0000 -0.0000  0.0000  0.0000  0.0000 -0.0000
# X10  0.0000 -0.0000  0.0000 -0.0000 -0.0000 -0.0000 -0.0000 -0.0000 -0.0000
# X11  0.0000 -0.0000  0.0000 -0.0000 -0.0000  0.0000  0.0000  0.0000  0.0000
# ...

# %%
from sklearn import preprocessing

# %%
cdf.head()
# Out:
#        X1  X2  X3  X4  X5  X6  X7  X8  X9  X10  ...    X15    X16    X17  \
# 0   20000   2   2   1  24   2   2  -1  -1   -2  ...      0      0      0
# 1  120000   2   2   2  26  -1   2   0   0    0  ...   3272   3455   3261
# 2   90000   2   2   2  34   0   0   0   0    0  ...  14331  14948  15549
# 3   50000   2   2   1  37   0   0   0   0    0  ...  28314  28959  29547
# 4   50000   1   2   1  57  -1   0  -1   0    0  ...  20940  19146  19131
#
#     X18    X19    X20   X21   X22   X23  Y
# 0     0    689      0     0     0     0  1
# 1     0   1000   1000  1000     0  2000  1
# 2  1518   1500   1000  1000  1000  5000  0
# 3  2000   2019   1200  1100  1069  1000  0
# 4  2000  36681  10000  9000   689   679  0
#
# [5 rows x 24 columns]

# %%
pcsSummary_df = pd.DataFrame({'Standard deviation': np.sqrt(pcs.explained_variance_),
                             'Proportion of variance': pcs.explained_variance_ratio_,
                             'Cumulative proportion': np.cumsum(pcs.explained_variance_ratio_)
                             })

pcsSummary_df = pcsSummary_df.transpose()
pcsSummary_df.columns = ['PC{}'.format(i) for i in range(1, len(pcsSummary_df.columns) + 1)]
pcsSummary_df.round(4)
# Out:
#                                 PC1          PC2         PC3         PC4  \
# Standard deviation      166526.3231  115824.3723  37236.4283  27730.3966
# Proportion of variance       0.6105       0.2953      0.0305      0.0169
# Cumulative proportion        0.6105       0.9058      0.9363      0.9532
#
#                                PC5         PC6         PC7         PC8  \
# Standard deviation      20686.6242  20266.0848  18511.5323  17030.1453
# Proportion of variance      0.0094      0.0090      0.0075      0.0064
# Cumulative proportion       0.9627      0.9717      0.9792      0.9856
#
#                                PC9        PC10  ...    PC15    PC16    PC17  \
# Standard deviation      16283.1702  11608.9772  ...  2.0658  0.9421  0.7532
# Proportion of variance      0.0058      0.0030  ...  0.0000  0.0000  0.0000
# Cumulative proportion       0.9915      0.9944  ...  1.0000  1.0000  1.0000
#
#                           PC18    PC19    PC20   PC21    PC22    PC23    PC24
# ...

# %%
pcsComponents_df = pd.DataFrame(pcs.components_.transpose(), 
                                columns=pcsSummary_df.columns,
                                index=cdf.columns
                                )
pcsComponents_df.iloc[:,:4]
# Out:
#               PC1           PC2           PC3           PC4
# X1   4.915809e-01  8.690291e-01 -2.057808e-02 -1.843015e-02
# X2  -3.492620e-08  1.758002e-07  3.244874e-07 -2.351185e-08
# X3  -3.665019e-07 -1.499181e-06 -9.730797e-07  2.066892e-07
# X4  -1.919951e-07 -4.015695e-07  7.375978e-08  9.609169e-08
# X5   5.569764e-06  8.277923e-06 -4.191445e-06 -3.257900e-07
# X6   3.417795e-07 -3.803268e-06 -4.156828e-07 -2.627138e-06
# X7   5.676345e-07 -4.622638e-06 -5.847159e-07 -2.669580e-06
# X8   5.815621e-07 -4.496857e-06  5.080617e-07 -1.786945e-06
# X9   6.646776e-07 -4.258792e-06  2.100704e-06  2.256457e-07
# X10  7.579551e-07 -4.030164e-06  3.455139e-06 -8.764888e-07
# X11  8.358994e-07 -3.982517e-06  4.451784e-06 -2.238435e-06
# X12  3.884521e-01 -2.213574e-01 -5.489635e-01 -2.049847e-01
# X13  3.813556e-01 -2.263788e-01 -3.909324e-01 -3.762808e-02
# X14  3.721866e-01 -2.165145e-01 -4.810317e-02  5.534895e-01
# X15  3.464081e-01 -1.940395e-01  2.610328e-01  7.910290e-02
# ...

# %%
pcsComponents_df.PC1.nlargest(3)
# Out:
# X1     0.491581
# X12    0.388452
# X13    0.381356
# Name: PC1, dtype: float64

# %%
pcsComponents_df.PC1.idxmax()
# Out:
# 'X1'

# %%
pcsComponents_df.PC1.nsmallest(3)
# Out:
# X3   -3.665019e-07
# X4   -1.919951e-07
# Y    -1.753425e-07
# Name: PC1, dtype: float64

# %%
pcsComponents_df.PC1.nsmallest(3)
# Out:
# X4   -8.198425e-08
# Y    -3.745344e-08
# X3    4.147639e-08
# Name: PC1, dtype: float64

# %% [markdown]
# *   ¿Cuál es el número de componentes mínimo y por qué?
#
#     *Considero que utilizar al menos 5 sería bastante conveniente, pues se reduce bastante la información total presentada y también se mantiene un 95% de toda la proporción acumulada de la varianza.*
#
# *   ¿Cuál es la variación de los datos que representan esos componentes?
#
#     *Es del 95% de la variabilidad total.*
#
# *   ¿Cuál es la pérdida de información después de realizar PCA?
#
#     *Sería sólo del 5% en cuanto a la variabilidad total, pero se estarían eliminando más de 15 columnas que se consideraban inicialmente.*
#
# *   De las variables originales, ¿Cuál tiene mayor y cuál tiene menor importancia en los componentes principales?
#
#     *En este caso la variable que tiene mayor importancia sería la columna 'X12'; y la de menor importancia sería 'X3'*
#
# *   ¿Cuándo se recomienda realizar un PCA y qué beneficios ofrece para Machine Learning?
#
#     Cuando se tengan muchos datos dentro del dataframe a analizar, de este modo se puede mantener la mayor parte de la información presente y paralelamente se reduce en gran medida la información total a analizar.*
